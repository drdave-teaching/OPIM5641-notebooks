# %% [markdown]
# <img src="data:image/svg+xml;base64,..." width="100%" alt="OPIM5641 banner"/>
#
# # Week5 BDM Spring2025 Live
# ### OPIM 5641 — Business Decision Modeling · Module4
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drdave-teaching/OPIM5641-notebooks/blob/main/Module4/Week5_BDM_Spring2025_Live.ipynb)
#
# *Run me top to bottom — **Runtime → Run all**. Data loads from a stable link, so there's nothing to upload.*

# %% [markdown]
# # Warm up! Take out paper and pencil.

# %% [markdown]
# Monte Carlo simulation.
#
# Assume the following:
# * We go to work for 30 years
# * We make 100K
# * We get a 5% raise every year
# * We contribute 10% of our salary to retirement
# * Stock market returns = mean(7%), sd(17%)
# * 10 k iterations
# ... go!
