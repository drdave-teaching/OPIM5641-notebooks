# %% [markdown]
# <img src="data:image/svg+xml;base64,..." width="100%" alt="OPIM5641 banner"/>
#
# # OPIM5641 Build Build Build
# ### OPIM 5641 — Business Decision Modeling · Module4
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drdave-teaching/OPIM5641-notebooks/blob/main/Module4/OPIM5641_BuildBuildBuild.ipynb)
#
# *Run me top to bottom — **Runtime → Run all**. Data loads from a stable link, so there's nothing to upload.*

# %% [markdown]
# # Group Project
# Groups of two students. Sign-up on HuskyCT.

# %% [markdown]
# # Your GitHub Repo
# * Add your link here so I can run your package - have enough info in the README for me to understand what to do!

# %% [markdown]
# # Roadmap
# * November 4th - recap of Ms. Womack and introduction to binary constraints. Everyone should have a flexible Ms. Womack and a data download script prepared.
# * November 11th - Include the integer constraints (one stock from each group, no more than 5 from each group.) Your Ms. Womack script should work with real data and have real outputs.
# * November 18th - work together to make a Python package on GitHub.
# * November 25th - test your script, make it pretty and easy to use. Be creative!
# * December ~2nd - finalize your code, ask questions.
# * December 5th - submit to Dave for grading.

# %% [markdown]
# # 📊 OPIM 5641 Final Project — Simple Rubric (Portfolio Optimization)
#
# **Goal:** Start with the in-class (Ms. Womack) example in Colab, then switch to real monthly stock data and produce **three portfolios**:
# - **Conservative / diversified** (min risk, a little bit of everything)
# - **Aggressive / all-in** (max return)
# - **Balanced / middle** (tradeoff, top left corner of efficient frontier - code this, don't pick automatically)
#
# Build your model on at least a year of monthly data, then test it for October 1 - November 1, 2025. How does your model do?!
#
# ---
#
# ## ✅ Grading (keep it simple)
#
# ### 1) Proof of Concept — Ms. Womack (20%)
# - Load the provided CSV in Colab.
# - Compute mean returns and a covariance matrix.
# - Solve one simple allocation (weights sum to 1, must make at least 1.5%).
# - Show  table of weights (proportion allocated) and efficient frontier.
#
# ### 2) Real Data Function — Yahoo Finance (20%)
# - Write **one function** that downloads **monthly prices**, cleans them, and returns **monthly returns**.
# - Inputs: tickers, start, end. Output: clean returns DataFrame.
# - Print the mean vector and covariance you’ll use for September 2024 through September 2025.
#
# ### 3) Real Data in the Same Framework (20%)
# - Reuse your PoC code on the real-data returns.
# - Constraints: weights sum to 1; 0 ≤ weights ≤ 1.
# - Add **one** simple extra constraint (like must pick one stock from each sector, or if you invest in a stock, you must use 2% of your money, no more than 10% etc.)
# - Produce **three portfolios**: conservative, aggressive, balanced.
#
# ### 4) Make It Reusable (20%)
# - Put core code into a tiny module/package (2–3 files is fine) that we can all access from GitHub.
# - One easy entrypoint (function or script) that:
#   1) downloads data → 2) computes returns → 3) builds 3 portfolios → 4) prints a comparison table + 1–2 plots.
# - Add a short README: “how to run,” inputs, outputs.
#
# ### 5) Creativity & Repo Quality (20%)
# - Clean Colab and repo, clear README, nice labels on plots.
# - Any small extra (e.g., a better chart, a tiny CLI, or a simple robustness check).
# - Students will grade the projects from best to worst - Dave will use this to alter points. Best rankings get best grade, worst rankings get worst grade.
#
#
# ---
#
# ## 📦 What to Submit
# - **Colab notebook** (PoC + real data demo) - HuskyCT.
# - **Small module/package** folder. - give me your repo as a comment and make sure it's public so I can download and run the function.
# - **Outputs:** one comparison table (weights + expected return + variance) and **two plots** (e.g., proportion allocated + efficient frontier).

# %% [markdown]
# # Week 1 Progress (Nov 4, 2025)
# * You can download and process monthly returns for your 15 stocks over the past 3 years.
# * You have a basic Ms. Womack example - and you generalized it to take a .csv with one date column and X stocks... and it runs. You can do it with the Ms. Womack data and compare your outputs to the class example.
#   * You can also run your data and generate cool plots!
#   * Be careful of the upper risk level.
# * Before class nexzt week, you need tighten this up. I think you could have two functions feeding into each other.\
#   * One function will create the monthly returns for any number of stocks.
#   * One function will run the optimization model and generate the efficient frontier and stock allocation graphs.
#
# When I look at your code next week, I want to see these two functions. I'm going to pick random stock symbols and your code should run!
#
# What is the optimal value of upper risk limit? It's PROBABLY the max value in the weighted cov matrix where p=1. Try this and let me know! Keep up the momentum.

# %% [markdown]
# # Week 2: Up and running!
# You and your buddy are side-by-side, ready to rock.
#
# One of you has the data download function (`download_stock_data`) and it should spit out the:
# * covariance matrix
# *  the average returns per stock.
#
# The other student has the generalized Ms. Womack example (`run_mpt`) and it should spit out the efficient frontier graph, the stock allocation graph, and the data that is used to make those graphs.
# * Stock allocation per risk level: table
# * Efficient frontier (risk/reward): table
# * Spaghetti plot: figure
# * Efficient frontier (risk/reward): table

# %% [markdown]
# ## Your goal before Week 3...
# Make sure that you are able to push your code to Github and let anyone run it! I will go around the room to make sure I can download your code, fit your models, and visualize the output.
#
# My code example is here: it's 90% there... https://github.com/drdave-teaching/bdm_fall2025_opt
#
# * Emulate my structure
# portfolio-pipeline/
# ├─ README.md
# ├─ requirements.txt
# ├─ .gitignore
# ├─ LICENSE
# ├─ src/
# │  └─ portfolio_pipeline.py   # your two functions + the glue
# └─ main.py                    # CLI entrypoint so anyone can run it
#
# * It can be tough to get the solvers (IPOPT) to download... ask your favorite LLM to help you do this download more elegantly. It probably has to go in the `requirements.txt` file.
# * It can be tough for the images of efficeint frontier and prop allocated to show - maybe you need to download them instead of printing them out?

# %% [markdown]
# # 🔴 Andrew and Joseph: The Market Mavericks

# %%
# !git clone https://github.com/Andrew6695/bdm_fall2025_opt.git
# Out:
# fatal: destination path 'bdm_fall2025_opt' already exists and is not an empty directory.

# %%
# change the working dir
# %cd /content/bdm_fall2025_opt
# Out:
# /content/bdm_fall2025_opt

# %%
# print working directory
# %pwd
# Out:
# '/content/bdm_fall2025_opt'

# %%
# python3 -m venv .venv
# source .venv/bin/activate  # macOS/Linux
# # .venv\\Scripts\\Activate.ps1  # Windows PowerShell

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.8/306.8 kB 22.7 MB/s eta 0:00:00
# ...

# %%
# !idaes get-extensions --to /content/bin
# Out:
# Getting files...
# Done
# -----------------------------------------------------------------
# IDAES Extensions Build Versions
# ...
# Solvers:  v3.4.2 20240811 ubuntu2204-x86_64
# Library:  v3.4.2 20240811 ubuntu2204-x86_64
#
# ...

# %%
# !python main.py --tickers GE KO NVDA --ipopt-path /content/bin/ipopt
# Out:
# Monthly returns shape: (48, 3)
# Monthly returns head:
#                   GE        KO      NVDA
# Ticker            GE        KO      NVDA
# Date
# 2020-01-31  0.043588  0.062011 -0.014505
# 2020-02-29 -0.126104 -0.084075  0.142283
# 2020-03-31 -0.270221 -0.172743 -0.023957
# 2020-04-30 -0.143577  0.037062  0.108801
# 2020-05-31 -0.033824  0.017215  0.214657
# Solving 200 portfolio problems from cap=3.209e-03 to 3.350e-02...
# Figure(800x500)
# Figure(1000x600)

# %% [markdown]
# ## Feedback
# * Great job! Oppt for improvement:
#   * Saving figures in a folder called '/output'
#   * Give an example of using the script with a date range (start date, end date)
#   * Paper testing - train a model with start/end (Jan 2024 - July 2025)... then evaluate on August, Sept, October... how did your model do vs. just equal weighting or buying the S&P500 or Bitcoin?
#     * Add this line of code... prints images?
#
# ```python
# %matplotlib inline
# import matplotlib
# matplotlib.use('module://matplotlib_inline.backend_inline')
# ```

# %% [markdown]
# # 🔴 Anushka and Shruti: Innovate & Elevate
#
# * https://github.com/anushkarajoriya14/BDM_Allocation_Model/tree/main/portfolio-pipeline
# * https://colab.research.google.com/drive/1eIu00JxRUpHVlQrfzwJUGm6pk_w8bmVx#scrollTo=2luW5tDkOeKi

# %% [markdown]
# ## Feedback
# * Great job! Make it more concise - your `%run main.py` code is good, but there's too much prep beforehand
# * Your images actually printed out well!!!
#   * You may want to dump them in an `/outputs` folder
# * Add a line to install requirements.txt
# * Install idaes-pse a little more elegantly
#   * Add idaes-pse to your requirements file... then....
#   * !idaes get-extensions --to /content/bin

# %% [markdown]
# # 🔴 Niharika, Usman and Arijita: Strategic Synergy
#
# * https://github.com/nihasharma21/BDM-Project/tree/main/portfolio-pipeline
# *

# %% [markdown]
# ## Feedback
# * Amazing! Your easy to use tutorial is appreciated.
#
# ```python
# #Resetting to a clean workspace
# %cd /content
# !rm -rf BDM-Project
#
# !git clone https://github.com/nihasharma21/BDM-Project.git
# %cd BDM-Project/portfolio-pipeline
# !python -m pip install -r requirements.txt
#
# #!python -m idaes get-extensions --to ./bin
#
# # !pip install idaes-pse --pre
# !idaes get-extensions --to ./bin
#
# !ls bin
#
# TICKERS = "NFLX T CMCSA META LYV AAPL ADBE PLTR CSCO MSFT EQIX ESS DLR VTR SBAC"
# !python main.py --ipopt ./bin/ipopt --start 2022-01-01 --end 2024-01-01 --tickers {TICKERS}
# ```

# %% [markdown]
# My feedback to you all is to:
# * Save all outputs to an output_dir (./output_dir/) ... set this as an environment variable or as a keyword argument...
# * Add the inline plotting from `matplotlib` if you want to generate images on the fly in the output cell.
# * Make a nice readme and a tutorial for everyone to follow (see my feedback above 'Market Mavericks'... you should also be able to do 'paper trading').

# %% [markdown]
# # 🔴 Luke and Farhan: Alpha & Omega Algorithms

# %%
# Resetting to a clean workspace
# %cd /content
# !rm -rf BDM-Project

# !git clone https://github.com/lukewbauer/stock-portfolio-optimization.git
# Out:
# /content
# Cloning into 'stock-portfolio-optimization'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 41 (delta 11), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 284.60 KiB | 4.74 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd ./stock-portfolio-optimization/

# %%
# !python -m pip install -r requirements.txt

# !python -m idaes get-extensions --to ./bin

# !pip install idaes-pse --pre
# !idaes get-extensions --to ./bin

# !ls bin

TICKERS = "NFLX T CMCSA META LYV AAPL ADBE PLTR CSCO MSFT EQIX ESS DLR VTR SBAC"
# !python main.py --ipopt ./bin/ipopt --start 2022-01-01 --end 2024-01-01 --tickers {TICKERS}
# Out:
# ERROR: Invalid requirement: "if 'google.colab' in sys.modules:": Expected end or semicolon (after name and no valid version specifier)
#     if 'google.colab' in sys.modules:
#        ^ (from line 10 of requirements.txt)
# /bin/bash: line 1: idaes: command not found
# ls: cannot access 'bin': No such file or directory
# ...
#
# ✓ Price data downloaded.
#
# === Adjusted Close Prices ===
# Figure(1200x600)
# === Monthly Returns ===
# Figure(1000x800)
# Figure(1000x800)
# Figure(1200x600)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
#
# === First 5 Allocation Rows ===
#
# === First 5 Reward Rows ===
# ...
#
# ✓ Price data downloaded.
#
# === Adjusted Close Prices ===
# Figure(1200x600)
# === Monthly Returns ===
# Figure(1000x800)
# Figure(1000x800)
# Figure(1200x600)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
#
# === First 5 Allocation Rows ===
#
# === First 5 Reward Rows ===
# Pipeline completed successfully!

# %% [markdown]
# ## Feedback
# * Solid job here! We can update the code to get rid of `display` (DW to do a pull request)
# * Add each other as a collaborator on your script. You all can add me as a collaborator too! `drdave-teaching`
# * Add a version (you did it!)
# * consider dumping outputs to a folder, inline images should show if you want them to... it likes some outputs from the fitted model aren't showing right away (and that's bc there was `display()` instead of `print()`

# %% [markdown]
# # 🚀 Week 3: Onwards and upwards!

# %% [markdown]
# It's time to keep pushing - your goal is to have something you are really proud of to show in a technical job interview. This is a great example of prescriptive analytics...
#
# ## v1: Mandatory
# I expect the following from all teams:
# * Easy to follow readme and tutorial (ipynb all filled out, ready to go.)
# * Easy to use package (keyword arguments make sense and allow for flexibility customization)
# * Outputs are stored in a folder (preferred) or printed out. JPEGs and .csv files.
# * Ideally, you will do pull requests and merge each team members code together (not required, but it's nice to see the graph here: https://github.com/lukewbauer/stock-portfolio-optimization/network - can you see my edit?)
# * Tag this basic version as v1 (or something related)
#
# ## v2: Advanced
# Eventually, teams will share their final repos and VOTE on who has the best content according to the following rubric:
# * Use of `bonmin` along with binary/activation variables: https://colab.research.google.com/drive/1-VKaMFCh1IOWVCU1Uhb9IvP1boWgVnyN?authuser=1
# * logic like choose at least N stocks, one from each group or sector (find out if you can get a list of sectors from WIKI to reference: https://en.wikipedia.org/wiki/List_of_S%26P_500_companies)
# * linking constraints (if you invest in a stock, you must invest at least 2%, no more than 20%)
# * Specify low, medium and high risk scenarios (equal weighting/low risk, top left of efficient frontier, dump all in one stock)
# * Paper trading: if you fit your model on Jan 2024 - July 2025... how would your model have done
# * Tag this enhanced version as v2 or v3... the sky is the limit! Show off!
#
# I should be able to run v1 or v2 by just changing the version number when I clone it. You should have awesome documentation that shows how to run the basic and advanced versions.

# %% [markdown]
# # Grading
# Team submission. Everyone can earn up to 80 points for the v1... if you want a 100, do everything under v2. not required. You will be graded on quality by your peers. Peer feedback is 10%. Dave's feedback is 10%.

# %% [markdown]
# # How to run v1 vs. v2 from your repo...

# %%
# this failed :(
#!git clone https://github.com/lukewbauer/stock-portfolio-optimization@v1
# Out:
# Cloning into 'stock-portfolio-optimization@v1'...
# remote: Repository not found.
# fatal: repository 'https://github.com/lukewbauer/stock-portfolio-optimization@v1/' not found

# %%
import os

# Ensure we are in the /content directory to clone into new folders
# %cd /content

# --- Clone and checkout v1 ---
# Remove the directory if it already exists for a clean clone
# !rm -rf stock-portfolio-optimization-v1
# !git clone https://github.com/lukewbauer/stock-portfolio-optimization.git stock-portfolio-optimization-v1
# %cd stock-portfolio-optimization-v1
print(f"\nCurrent directory: {os.getcwd()}")
print("Checking out version v1 (commit c024510)...")
# !git checkout c024510
print("Successfully checked out v1. You are now in the v1 codebase.\n")

# --- Clone and checkout v2 ---
# Go back to /content to clone into a new directory
# %cd /content
# Remove the directory if it already exists for a clean clone
# !rm -rf stock-portfolio-optimization-v2
# !git clone https://github.com/lukewbauer/stock-portfolio-optimization.git stock-portfolio-optimization-v2
# %cd stock-portfolio-optimization-v2
print(f"\nCurrent directory: {os.getcwd()}")
print("Checking out version v2 (commit 16851e1)...")
# !git checkout 16851e1
print("Successfully checked out v2. You are now in the v2 codebase.")

# You can navigate to either directory to work with that specific version
# For example, to return to the v1 directory:
# %cd /content/stock-portfolio-optimization-v1
# Out:
# /content
# Cloning into 'stock-portfolio-optimization-v1'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 55 (delta 18), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (55/55), 290.32 KiB | 5.18 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# /content/stock-portfolio-optimization-v1
#
# Current directory: /content/stock-portfolio-optimization-v1
# Checking out version v1 (commit c024510)...
# Note: switching to 'c024510'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# ...
