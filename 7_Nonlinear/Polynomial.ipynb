# %% [markdown]
# <img src="data:image/svg+xml;base64,..." width="100%" alt="OPIM5641 banner"/>
#
# # Polynomial
# ### OPIM 5641 — Business Decision Modeling · Module4
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drdave-teaching/OPIM5641-notebooks/blob/main/7_Nonlinear/Polynomial.ipynb)
#
# *Run me top to bottom — **Runtime → Run all**. Data loads from a stable link, so there's nothing to upload.*

# %%
# # here is the zip file
# !gdown 10XRvLZqrpSNiXVAN-pipU52BVRwoGcNQ

# %%
# %%capture
import sys
import os

if 'google.colab' in sys.modules:
    # !pip install idaes-pse --pre
    # !idaes get-extensions --to ./bin
    os.environ['PATH'] += ':bin'

# %%
# !pip install pyomo
# Out:
# Requirement already satisfied: pyomo in /usr/local/lib/python3.12/dist-packages (6.9.4)
# Requirement already satisfied: ply in /usr/local/lib/python3.12/dist-packages (from pyomo) (3.11)

# %% [markdown]
# # Nonlinear Programming (Polynomial Intro)
# **OPIM 5641: Business Decision Modeling - Dept. of Operations and Information Management - University of Connecticut**
#
# Let's learn about the 'hill climber in the fog' and why intitial conditions can yield different answers!
#
# ------------------------------------
#
# Related Readings:
# * `Powell`: Chapter 8 (Nonlinear Optimization)

# %% [markdown]
# ## Motivation for nonlinear programming
#
# When Dantzig presented the simplex algorithm, his work was heavily criticized by some of his fellow academic colleagues, as the method applied solely to linear programs. One of the critics said that the method was not really useful, as the world was highly nonlinear. Today the simplex algorithm is recognized as one of the biggest achievements of the last century, but this did not change the fact that world is indeed highly nonlinear.
#
# In this module, we will see the pros and cons of nonlinear programming. A major pro is the fact that the modeling tasks becomes relatively simpler, as we do not have to worry about linearity contraints any longer. Namely, you can multiply variables, take square roots, logs, absolute values, etc. This is important because some problems cannot be properly modeled as linear programs. On the other hand, whereas the modeling task is easier, the identification of optimal solutions becomes significantly harder. Whereas the simplex algorithm will necessarily give you an optimal solution (if you wait for its termination), we never really know whether the solution we have for some arbitrary nonlinear model is actually optimal or not. We will see these aspect in the example presented in this notebook.
#
# After reading this notebook, you should understand that:
# * Don't forget to initialize the decision variables when working with nonlinear models (more details below);
# * Try different initial values for the decision variables (you will understand why below);
# * If you can infer lower and upper bounds for your decision variables, **use them**!
# * Use linear models if you can

# %% [markdown]
# ## Setup Your Environment/Imports
#
# In this module we will use [Ipopt](https://coin-or.github.io/Ipopt/), a solver capable of addressing nonlinear models.

# %%
# before you do anything...
# mount your drive!
# click folder on the left...
# import modules

# %matplotlib inline
from pylab import *

import shutil
import sys
import os.path


from pyomo.environ import *

# # this is the file we just uploaded to the runtime
# !unzip -o -q ipopt-linux64_dw
# assert(shutil.which("ipopt") or os.path.isfile("ipopt"))

# %% [markdown]
# # Polynomials (extracted from the textbook)
#
#
# Suppose you are a manufacturer of widgets. You are interested in finding the price to sell your widgets at in order to maximize the number of units purchased.  Consultants have modeled the relationship between price $𝐩$ and number of units sold $𝐧$ as
#
# $n(p) = 𝟑𝟎𝟎+𝟑𝟎𝟎𝐩−𝟔𝟎𝐩^𝟐−𝟏𝟕.𝟓𝐩^𝟑+𝟓.𝟑𝟐𝐩^𝟒−𝟎.𝟑𝟑𝐩^𝟓$
#
# What value of $p$ results in the maximum number of units sold? Is it possible to model this problem as a linear program?

# %% [markdown]
# **Objective Function**
#
# $\max 300 + 300p - 60p^2 - 17.5p^3 + 5.32p^4 - 0.33p^5$ `objective function`
#
# subject to:
#
# * $p \in \mathbb{R}^+$ `(Domain)`

# %% [markdown]
# ## Pro of nonlinear optimization: nonlinear models are simpler to design!
#
# ... but we will see that the initialization value will have an impact in the results. First, we will initialize p to 1.

# %%
# declare the model
model = ConcreteModel()

# declare decision variables  - Initialize variable to 1.0
model.p = Var(domain=NonNegativeReals, initialize=1)

# alternative way of initializing a decision variable
# model.p.value = 1

# declare objective
model.cost = Objective(
                      expr = 300 + 300*model.p - 60*model.p**2 - 17.5*model.p**3 + 5.32*model.p**4 - 0.33*model.p**5,
                      sense = maximize)

# show the model you've created
model.pprint()
# Out:
# 1 Var Declarations
#     p : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :     1 :  None : False : False : NonNegativeReals
#
# 1 Objective Declarations
#     cost : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 300 + 300*p - 60*p**2 - 17.5*p**3 + 5.32*p**4 - 0.33*p**5
#
# 2 Declarations: p cost

# %%
# solve it
SolverFactory('ipopt', executable='/content/bin/ipopt').solve(model).write()
# show the results
print("Objective value = ", model.cost())
print("p = ", model.p())
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.10585141181945801
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# Objective value =  594.7075738826653
# p =  1.9522920273351378

# %% [markdown]
# ## Trying a different initial value
#
# The optimal solution when we start the model using p = 1 is 594.71, with p = 1.95. Let's see what happens when we start the model using p = 9...

# %%
# declare the model
model = ConcreteModel()

# declare decision variables  - Initialize variable to 9
model.p = Var(domain=NonNegativeReals, initialize=9)

# declare objective
model.cost = Objective(
                      expr = 300 + 300*model.p - 60*model.p**2 - 17.5*model.p**3 + 5.32*model.p**4 - 0.33*model.p**5,
                      sense = maximize)

# solve it
SolverFactory('ipopt', executable='/content/bin/ipopt').solve(model).write()
# show the results
print("Objective value = ", model.cost())
print("p = ", model.p())
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.03035736083984375
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# Objective value =  900.1036703801037
# p =  8.363800878594732

# %% [markdown]
# ## Solution changed after we selected a new initial value for $p$
#
# Whereas starting from $p = 1$ gave as optimal value 594.71 and optimal $p = 1$, starting from $p = 9$ gave us optimal value 900.10 an optimal $p = 8.36$. Let's plot this function, just to see if we are close to the optimal value.

# %%
import matplotlib.pyplot as plt
import numpy as np

# 100 linearly spaced numbers
x = np.linspace(0,10,1000)

# our function
y = 300 + 300*x - 60*x**2  - 17.5*x**3 + 5.32*x**4 - 0.33*x**5

#print(y)

# setting the axes at the centre
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# labels
plt.xlabel('p')
plt.ylabel('n(p)')

# plot the function
plt.plot(x,y, 'g')

# show the plot
plt.show()

# %% [markdown]
# ## Con of nonlinear optimization: you may not know whether your solution is optimal!
#
#
# The first solution was a **local optimum**, whereas the second one is a **global optimum**. However, we could not tell a priori whether the first solution was only a local optimum. In this example, we know that the second solution is not only a local optimum, but also a global optimum. In general, though, we cannot check that, and this is why nonlinear models are challenging to solve (even though they are usually easier to model).
#
# ## Remember the recommendations:
# * Don't forget to initialize the decision variables (as you can see, the initial value matters)
# * Try different initialization values when solving nonlinear optimization problems

# %% [markdown]
# ## Bounding the decision variables
# Let's add another experiment where we put bounds on the decision variables - it will help bound the solution and will fit faster, but you may miss the optimal solution.

# %%
import matplotlib.pyplot as plt
import numpy as np

# 100 linearly spaced numbers
x = np.linspace(0,10,1000)

# our function
y = 300 + 300*x - 60*x**2  - 17.5*x**3 + 5.32*x**4 - 0.33*x**5

#print(y)

# setting the axes at the centre
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# labels
plt.xlabel('p')
plt.ylabel('n(p)')

# vertical lines for simulated bounds
# we will use 1 and 7
plt.vlines(x=1, ymin=0, ymax=1000, color='red', linestyles='dashed')
plt.vlines(x=7, ymin=0, ymax=1000, color='red', linestyles='dashed')

# plot the function
plt.plot(x,y, 'g')

# show the plot
plt.show()

# %% [markdown]
# And here's how we would put bounds on the decision variables. You can also mess with the initial values.

# %%
# declare the model
model = ConcreteModel()

# declare decision variables  - bounds and initial values
# try p=4 vs. p=5 and compare the results
# looks like 4.869 is roughly the decision boundary
model.p = Var(domain=NonNegativeReals, bounds=(1,7), initialize=5)

# declare objective
model.cost = Objective(
                      expr = 300 + 300*model.p - 60*model.p**2 - 17.5*model.p**3 + 5.32*model.p**4 - 0.33*model.p**5,
                      sense = maximize)

# solve it
SolverFactory('ipopt', executable='/content/bin/ipopt').solve(model).write()
# show the results
print("Objective value = ", model.cost())
print("p = ", model.p())
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.036095619201660156
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# Objective value =  684.5100000000011
# p =  7.0

# %% [markdown]
# # Uncertainty in the parameters - Monte Carlo
#
# Let's see now how the quality of our two "optimal" solutions change if we assume that the parameters of the polynomial may change within a range of 10%.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Parameters
a = 300
b = 300
c = 60
d = 17.5
e = 5.32
f = 0.33

# Optimal solutions
p1 = 1.95
p2 = 8.36

# List of results
results1 = list()
results2 = list()

# Errors
error = 0.01
low_range = 1 - error
high_range = 1 + error

for k in range(10000):
  aa = a*np.random.uniform(low=low_range,high=high_range)
  bb = b*np.random.uniform(low=low_range,high=high_range)
  cc = c*np.random.uniform(low=low_range,high=high_range)
  dd = d*np.random.uniform(low=low_range,high=high_range)
  ee = e*np.random.uniform(low=low_range,high=high_range)
  ff = f*np.random.uniform(low=low_range,high=high_range)

  nn1 = aa + bb*p1 - cc*p1**2 - dd*p1**3 + ee*p1**4 - ff*p1**5
  nn2 = aa + bb*p2 - cc*p2**2 - dd*p2**3 + ee*p2**4 - ff*p2**5

  results1.append(nn1)
  results2.append(nn2)

# %% [markdown]
# ## Quality of the first solution

# %%
print("Mean of first solution:",np.mean(results1))
sns.kdeplot(results1)
plt.show()
# Out:
# Mean of first solution: 594.7294367741763

# %% [markdown]
# ## Quality of the second solution

# %%
print("Mean of second solution:",np.mean(results2))
sns.kdeplot(results2)
plt.show()
# Out:
# Mean of second solution: 899.1280819193873

# %% [markdown]
# # [optional] Make a surface
# On your own, you can try to make a surface and update the objective function to find the maximum of a surface in 2 dimensions

# %% [markdown]
# # Use Sampling to Search the Solution Space

# %%
import numpy as np
results = []

for a in np.arange(0,1000,1):
  # pick a random number
  x = np.random.uniform(low=0,high=10,size=1)

  # declare the model
  model = ConcreteModel()

  # declare decision variables  - bounds and initial values
  # try p=4 vs. p=5 and compare the results
  # looks like 4.869 is roughly the decision boundary
  model.p = Var(domain=NonNegativeReals, bounds=(1,7), initialize=x[0])

  # declare objective
  model.cost = Objective(
                        expr = 300 + 300*model.p - 60*model.p**2 - 17.5*model.p**3 + 5.32*model.p**4 - 0.33*model.p**5,
                        sense = maximize)

  # solve it
  SolverFactory('ipopt', executable='/content/bin/ipopt').solve(model).write()
  # show the results
  #print("Objective value = ", model.cost())
  #print("p = ", model.p())

  tmp = [x[0], model.p(), model.cost()]
  results.append(tmp)
print("I'm Done!")
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.030863285064697266
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.030659914016723633
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.06334972381591797
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `0.5733264234061808` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.04324078559875488
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.03002190589904785
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `8.85653030106272` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.02068495750427246
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.0236814022064209
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.027825117111206055
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.017986536026000977
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.0235595703125
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.025990962982177734
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `8.783099675050693` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.03568601608276367
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.027461528778076172
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `8.978091733931231` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.018715381622314453
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.03633522987365723
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.026242971420288086
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `0.7959129218870298` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.048307180404663086
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.044773101806640625
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.03636741638183594
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.04276847839355469
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.025005340576171875
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.020997285842895508
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `7.962086977795863` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.01853156089782715
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `7.6607379250427075` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.025622129440307617
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.022684335708618164
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.022308826446533203
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.0329594612121582
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.03148245811462402
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `0.3413703926578915` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.027796506881713867
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.02329730987548828
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.02402520179748535
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.025506258010864258
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.019264936447143555
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.021777868270874023
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.02556920051574707
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.030753135681152344
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.022266626358032227
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `9.865379535233023` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.018957138061523438
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `0.6572497953780021` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.03514528274536133
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `7.905909454792411` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.029580116271972656
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `7.034723053241763` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.027880191802978516
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.045789480209350586
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.03336691856384277
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.024865150451660156
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `8.640823290951376` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.05854487419128418
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `8.682029421242628` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.049600839614868164
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `0.7186267759320908` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
# ...
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.023372650146484375
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.028383731842041016
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.036797285079956055
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.038675546646118164
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.029894590377807617
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.02464461326599121
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.02277684211730957
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `9.210877374000212` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.0285189151763916
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.030932188034057617
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.030521154403686523
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.03941154479980469
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# WARNING:pyomo.core:Setting Var 'p' to a numeric value `7.655515034112308` outside the bounds (1, 7).
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.022050142288208008
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.02222466468811035
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.024296998977661133
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.02218484878540039
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -.inf
#   Upper bound: .inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 1
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 0.02323460578918457
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# I'm Done!

# %%
results
# Out:
# [[np.float64(3.48419298952662), 1.9522920273370223, 594.7075738826654],
#  [np.float64(5.134286738983855), 7.0, 684.5100000000011],
#  [np.float64(6.548657998827303), 7.0, 684.5100000000011],
#  [np.float64(4.54602364338638), 1.9522920273370223, 594.7075738826654],
#  [np.float64(0.5733264234061808), 1.95229202735625, 594.7075738826653],
#  [np.float64(4.793116587821111), 1.9522920273370226, 594.7075738826653],
#  [np.float64(8.85653030106272), 7.0, 684.5100000000011],
#  [np.float64(4.109634779997274), 1.9522920273370221, 594.7075738826653],
#  [np.float64(6.726801716902656), 7.0, 684.5100000000011],
#  [np.float64(3.5197756326910943), 1.9522920273370223, 594.7075738826654],
#  [np.float64(6.081880562153918), 7.0, 684.5100000000011],
#  [np.float64(3.2908226079019656), 1.9522920273370226, 594.7075738826653],
#  [np.float64(8.783099675050693), 7.0, 684.5100000000011],
#  [np.float64(6.419336900755127), 7.0, 684.5100000000011],
#  [np.float64(8.978091733931231), 7.0, 684.5100000000011],
#  [np.float64(3.2551049568324233), 1.9522920273370221, 594.7075738826653],
#  [np.float64(6.532074534581877), 7.0, 684.5100000000011],
#  [np.float64(0.7959129218870298), 1.9522920273502957, 594.7075738826654],
#  [np.float64(2.9318867541209137), 1.9522920273370226, 594.7075738826653],
#  [np.float64(3