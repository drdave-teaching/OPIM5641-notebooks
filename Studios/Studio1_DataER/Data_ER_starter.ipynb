# %% [markdown]
# <img src="data:image/svg+xml;base64,..." width="100%" alt="OPIM5641 banner"/>
#
# # Studio 1 · Data ER - Starter
# ### OPIM 5641 - Business Decision Modeling · In-person lab
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drdave-teaching/OPIM5641-notebooks/blob/main/Studios/Studio1_DataER/Data_ER_starter.ipynb)
#
# *Work in pairs. FIRST: save your own copy (File → Save a copy in GitHub or Drive) - then work in YOUR copy.*

# %% [markdown]
# ## The situation
# A dataset just rolled into your emergency room: **income data for Connecticut places**, scraped by someone in a hurry. It looks a lot like the Massachusetts data from the async videos... but this patient has *multiple injuries*, and nobody wrote down what they are.
#
# **Your job (pairs, ~40 minutes):**
# 1. **Triage** - examine the patient and list EVERY problem you find. Don't fix yet - diagnose first.
# 2. **Treat** - clean the data, one problem at a time. Every fix gets a comment saying what you fixed.
# 3. **Discharge report** - three labeled plots + a one-paragraph insight a smart non-technical person would care about.
#
# **Deliverable:** your cleaned notebook committed to YOUR GitHub repo - 3 plots + the paragraph.
#
# 🔷 **The nugget:** in the async I *showed* you the traps. Today nobody tells you what's broken - finding out is the skill.

# %%
# import our libraries - every line has a comment, that's the house style!
import pandas as pd               # tables
import numpy as np                # math
import matplotlib.pyplot as plt   # plots

# %%
# the patient arrives - straight from the class repo
url = 'https://raw.githubusercontent.com/drdave-teaching/OPIM5641-notebooks/main/Studios/Studio1_DataER/ct_places_messy.csv'
df = pd.read_csv(url)
df.head(10)

# %% [markdown]
# ## Step 1 - Triage (diagnose, don't treat)
# Use `.shape`, `.info()`, `.dtypes`, `.describe()`, `.value_counts()`, `.duplicated()`, `.unique()` - whatever it takes. **List every injury you find as a markdown bullet below.** Hints about what KINDS of things to look for: think back to the async videos... then look harder, because this patient has injuries Massachusetts didn't.

# %%
# triage tools - start here and dig
print(df.shape)
df.info()

# %% [markdown]
# **Our triage findings (edit this cell - list every problem you find):**
# - injury 1: ...
# - injury 2: ...
# - injury 3: ...
# - (keep going - there are MORE than three)

# %% [markdown]
# ## Step 2 - Treat
# Fix each injury, one cell per fix, with a comment naming what you fixed. Order matters sometimes - think about which fix has to come first.
#
# **Caution:** exact-match filters beat `str.contains` - remember why.

# %%
# fix 1: (name it!)
# your code here

# %%
# fix 2: (name it!)
# your code here

# %%
# fix 3+: keep going until the patient is stable
# your code here

# %%
# prove it: dtypes numeric where they should be, row count you can defend, describe() that makes sense
df.info()
df.describe()

# %% [markdown]
# ## Step 3 - Discharge report
# Three labeled plots (your choice - bar? scatter? map, if you're feeling brave?) and ONE insight in a sentence, backed by a number.

# %%
# plot 1

# %%
# plot 2

# %%
# plot 3

# %% [markdown]
# **Our insight (edit this cell):** ...
#
# ## Step 4 - Commit it
# `File → Save a copy in GitHub` → your `opim5641-work` repo → commit message → done. That commit IS your deliverable.
#
# *Pssst... when you have data, you explore it. When you don't have data... come back after the break.*
